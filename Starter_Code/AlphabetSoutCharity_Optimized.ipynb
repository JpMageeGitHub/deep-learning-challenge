# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
application_df = application_df.drop(columns=["EIN", "NAME", "SPECIAL_CONSIDERATIONS"])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0   Association       1              0     5000              1
# 1  Co-operative       1         1-9999   108590              1
# 2   Association       1              0     5000              0
# 3         Trust       1    10000-24999     6692              1
# 4         Trust       1  100000-499999   142590              1

# %%
application_types_to_replace = ["T25", "T14", "T29", "T15", "T17", "T9", "T13", "T9", "T12", "T2"]
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
application_df["CLASSIFICATION"].value_counts()

application_df["CLASSIFICATION"].value_counts()[application_df["CLASSIFICATION"].value_counts()>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
classifications_to_replace = ["C7000", "C1700", "C4000", "C1270", "C2700", "C2800", "C7100", "C1230", "C7200", "C1240", "C8000", "C2300", "C1500", "C7120", "C1800", "C1250", "C1280", "C1238", "C1235", "C1260", "C2710", "C1245", "C1237", "C3200", "C0", "C1257", "C1267", "C1234", "C4120", "C7210", "C1720", "C1256", "C1265", "C2380", "C2570", "C1236", "C1900", "C1246", "C2600", "C2561", "C4500", "C4200", "C5200", "C1728", "C1283", "C6100", "C1820", "C3700", "C2566", "C2577", "C2170", "C2190", "C1239", "C2150", "C1727", "C8210", "C6100", "C2190", "C2150", "C1239", "C1727", "C8210", "C6100", "C2190", "C2150", "C1239", "C1727", "C8210", "C6100", "C2190", "C2150", "C1239", "C1727", "C8210", "C6100", "C2190", "C2150", "C1239", "C1727", "C8210", "C6100", "C2190", "C2150", "C1239", "C1727", "C8210", "C6100", "C2190", "C2150", "C1239", "C1727", "C8210", 
                              "C5000", "C1300", "C1400", "C6000", "C8200", "C1278", "C4100", "C2400", "C1600", "C1732", "C1570", "C2500", "C1580", "C1370", "C1248"]
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
application_df = pd.get_dummies(application_df)

# %%
features = application_df.drop(columns=["IS_SUCCESSFUL"])
target = application_df["IS_SUCCESSFUL"]
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=78)

# %%
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
layer1 = tf.keras.layers.Dense(units=90, activation="relu", input_dim=41)

# Second hidden layer
#  YOUR CODE GOES HERE
layer2 = tf.keras.layers.Dense(units=50, activation="linear")

#Additional hidden layer for optimization
layer3 = tf.keras.layers.Dense(units=20, activation="relu")



# Output layer
#  YOUR CODE GOES HERE
output_layer = tf.keras.layers.Dense(units=1, activation="sigmoid")

nn.add(layer1)
nn.add(layer2)
nn.add(layer3)
nn.add(output_layer)


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 90)                3780
#
#  dense_1 (Dense)             (None, 50)                4550
#
#  dense_2 (Dense)             (None, 20)                1020
#
#  dense_3 (Dense)             (None, 1)                 21
#
# ...
# Total params: 9,371
# Trainable params: 9,371
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
nn_fit = nn.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 6s 5ms/step - loss: 0.5714 - accuracy: 0.7211
# Epoch 2/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5570 - accuracy: 0.7289
# Epoch 3/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5547 - accuracy: 0.7296
# Epoch 4/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5530 - accuracy: 0.7313
# Epoch 5/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5512 - accuracy: 0.7320
# Epoch 6/200
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5511 - accuracy: 0.7322
# Epoch 7/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5497 - accuracy: 0.7330
# Epoch 8/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5489 - accuracy: 0.7335
# Epoch 9/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5492 - accuracy: 0.7331
# Epoch 10/200
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5647 - accuracy: 0.7254 - 513ms/epoch - 2ms/step
# Loss: 0.5646860599517822, Accuracy: 0.7253644466400146

# %%
nn.save("AlphabetSoupCharity_Optimized.h5")
